# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Load datasets
db1 = pd.read_csv('coem_authors_enriched.csv')
# db2 = pd.read_csv('embeddings2.csv')
# db3 = pd.read_csv('embeddings3.csv')

# %%
db1.columns
# Out:
# Index(['UUID', 'Author', 'LastName', 'Name', 'Birth Year', 'Death Year',
#        'Author_name', 'Summary', 'Wiki_URL', 'cats', 'linked_authors',
#        'country', 'genera'],
#       dtype='object')

# %%
authors = db1[['Author_name', 'linked_authors']]
authors.head()
# Out:
#         Author_name                                     linked_authors
# 0      Manuel Acuña                Francisco Sosa Escalante,José Martí
# 1               NaN                                                NaN
# 2  Delmira Agustini                                        Rubén Darío
# 3     Anna Ajmátova  Aleksandr Blok,Giacomo Leopardi,Joseph Brodsky...
# 4               NaN                                                NaN

# %%
# prompt: Convert all nan on db1['linked_authors'] and db1['Author_name'] to empty strings to all the column is strings

db1['linked_authors'] = db1['linked_authors'].fillna('')
db1['Author_name'] = db1['Author_name'].fillna('')

# %%
# prompt: A list of unique countries in db1

unique_countries = db1['country'].unique().tolist()
print(unique_countries)

# Get index of country and default 0
get_country_index = lambda country: unique_countries.index(country) if country in unique_countries else 0
country_index = get_country_index('fsdfd')
print(country_index)
# Out:
# ['Mexico', 'Uruguay', 'Rusia', 'Arabia', 'Al-Ándalus', 'España', 'Inglaterra', 'Italia', 'Puerto Rico', 'Portugal', 'Francia', nan, 'Guatemala', 'Grecia', 'Chile', 'Cuba', 'Irlanda', 'Venezuela', 'Argentina', 'Alemania', 'Estados Unidos', 'Republica Dominicana', 'Paraguay', 'Nicaragua', 'Colombia', 'Ecuador', 'Romano', 'Griego', 'Peru', 'Dinamarca', 'Argentino', 'El Salvador', 'Vietnam', 'Boliviano', 'Finlandia', 'Serbia', 'Costa Rica', 'Italiano', 'Austria', 'Brasil', 'Panamá', 'Honduras', 'Austríaco', 'Persa', 'Nigeria', 'India', 'Polonia', 'Japon', 'Gales', 'Palestina', 'Rumania', 'China', 'Belgica', 'África', 'Oriente', 'Estadounidense', 'Noruega', 'Suiza', 'Cubano', 'Bolivia', 'Suecia', 'Escocia', 'Líbano', 'Puertorriqueño', 'Sudáfrica', 'Prusia', 'Checoslovaquia', 'Reino Unido', 'Alemán', 'Inglesa', 'Egipto', 'Nueva Zelandia', 'Canadá', 'Trinidad y Tobago', 'Hungria', 'Chileno', 'Nueva', 'República', 'Spain', 'Estados', 'Santa', 'Sierra', 'Mónaco', 'Cabo', 'Marruecos', 'Republica Checa', 'Irán', 'Armenia', 'Madagascar', 'Guinea', 'Costa', 'Israel', 'Corea']
# 0

# %%
db1.columns
# Out:
# Index(['UUID', 'Author', 'LastName', 'Name', 'Birth Year', 'Death Year',
#        'Author_name', 'Summary', 'Wiki_URL', 'cats', 'linked_authors',
#        'country', 'genera'],
#       dtype='object')

# %% [markdown]
# ## Creating Linked Json

# %%
# prompt: Create a JSON with db1['Author_name'] and db['linked_authors'] fitting an object {nodes, links} where linked authors are separated by comma and iterated on

import json

nodes = []
links = []

for i, row in db1.iterrows():
    author_name = row['Author_name']
    linked_authors = row['linked_authors'].split(',')

    # if nan: continue
    if author_name == 'Nan' or author_name == '':
        continue

    # if author name already in node
    if author_name in [node['id'] for node in nodes]:
        continue

    """
    ['UUID', 'Author', 'LastName', 'Name', 'Birth Year', 'Death Year',
        'Author_name', 'Summary', 'Wiki_URL', 'cats', 'linked_authors',
        'country', 'genera']
    """

    # Create a node for the author
    node = {
        'id': author_name,
        'group': get_country_index(row['country']),
        'country': str(row['country']),
        'birth_year': str(row['Birth Year']),
        'death_year': str(row['Death Year']),
        'linked_authors': len(linked_authors)
    }
    nodes.append(node)

    # Create links for each linked author
    for linked_author in linked_authors:
        link = {
            'source': author_name,
            'target': linked_author,
            'value': 1
        }
        links.append(link)

# Create the JSON object
data = {
    'nodes': nodes,
    'links': links
}

# Save the JSON object to a file
with open('authorLinks.json', 'w') as outfile:
    json.dump(data, outfile,ensure_ascii=False)

# %%
for i in range(10):
    print(data['nodes'][i])

for i in range(10):
    print(data['links'][i])
# Out:
# {'id': 'Manuel Acuña', 'group': 0, 'country': 'Mexico', 'genera': 'Romanticismo', 'birth_year': '1849', 'death_year': '1873', 'linked_authors': 2}
# {'id': 'Delmira Agustini', 'group': 1, 'country': 'Uruguay', 'genera': 'Modernismo', 'birth_year': '1886', 'death_year': '1914', 'linked_authors': 1}
# {'id': 'Anna Ajmátova', 'group': 2, 'country': 'Rusia', 'genera': 'Romanticismo', 'birth_year': '1889', 'death_year': '1966', 'linked_authors': 6}
# {'id': 'Rafael Alberti', 'group': 5, 'country': 'España', 'genera': 'Romanticismo', 'birth_year': '1902', 'death_year': '1999', 'linked_authors': 16}
# {'id': 'Richard Aldington', 'group': 6, 'country': 'Inglaterra', 'genera': 'nan', 'birth_year': '1892', 'death_year': '1962', 'linked_authors': 1}
# {'id': 'Vicente Aleixandre', 'group': 5, 'country': 'España', 'genera': 'nan', 'birth_year': '1898', 'death_year': '1984', 'linked_authors': 65}
# {'id': 'Dante Alighieri', 'group': 7, 'country': 'Italia', 'genera': 'Romanticismo', 'birth_year': '1265', 'death_year': '1321', 'linked_authors': 6}
# {'id': 'Manuel A. Alonso', 'group': 8, 'country': 'Puerto Rico', 'genera': 'Romanticismo', 'birth_year': '1822', 'death_year': '1889', 'linked_authors': 1}
# {'id': 'Dámaso Alonso', 'group': 5, 'country': 'España', 'genera': 'nan', 'birth_year': '1898', 'death_year': '1990', 'linked_authors': 21}
# {'id': 'Manuel Altolaguirre', 'group': 5, 'country': 'España', 'genera': 'nan', 'birth_year': '1905', 'death_year': '1959', 'linked_authors': 17}
# {'source': 'Manuel Acuña', 'target': 'Francisco Sosa Escalante', 'value': 1}
# {'source': 'Manuel Acuña', 'target': 'José Martí', 'value': 1}
# {'source': 'Delmira Agustini', 'target': 'Rubén Darío', 'value': 1}
# {'source': 'Anna Ajmátova', 'target': 'Aleksandr Blok', 'value': 1}
# {'source': 'Anna Ajmátova', 'target': 'Giacomo Leopardi', 'value': 1}
# {'source': 'Anna Ajmátova', 'target': 'Joseph Brodsky', 'value': 1}
# {'source': 'Anna Ajmátova', 'target': 'Nicanor Parra', 'value': 1}
# {'source': 'Anna Ajmátova', 'target': 'Rabindranath Tagore', 'value': 1}
# {'source': 'Anna Ajmátova', 'target': 'Vladimir Nabokov', 'value': 1}
# {'source': 'Rafael Alberti', 'target': 'Federico García Lorca', 'value': 1}

# %%
# prompt: Go through the data and create a dataReduced only with the targets that exist in the nodes

dataReduced = {'nodes': [node for node in data['nodes']], 'links': []}

# Add links to dataReduced if their target exists in nodes
for link in data['links']:
    if link['target'] in [n['id'] for n in nodes]:
        dataReduced['links'].append(link)

# Print the reduced data
print(dataReduced)
# Out:
# {'nodes': [{'id': 'Manuel Acuña', 'group': 0, 'country': 'Mexico', 'genera': 'Romanticismo', 'name': 'Manuel', 'birth_year': '1849', 'death_year': '1873', 'linked_authors': 2}, {'id': 'Delmira Agustini', 'group': 1, 'country': 'Uruguay', 'genera': 'Modernismo', 'name': 'Delmira', 'birth_year': '1886', 'death_year': '1914', 'linked_authors': 1}, {'id': 'Anna Ajmátova', 'group': 2, 'country': 'Rusia', 'genera': 'Romanticismo', 'name': 'Anna', 'birth_year': '1889', 'death_year': '1966', 'linked_authors': 6}, {'id': 'Rafael Alberti', 'group': 5, 'country': 'España', 'genera': 'Romanticismo', 'name': 'Rafael', 'birth_year': '1902', 'death_year': '1999', 'linked_authors': 16}, {'id': 'Richard Aldington', 'group': 6, 'country': 'Inglaterra', 'genera': 'nan', 'name': 'Richard', 'birth_year': '1892', 'death_year': '1962', 'linked_authors': 1}, {'id': 'Vicente Aleixandre', 'group': 5, 'country': 'España', 'genera': 'nan', 'name': 'Vicente', 'birth_year': '1898', 'death_year': '1984', 'linked_authors': 65}, {'id': 'Dante Alighieri', 'group': 7, 'country': 'Italia', 'genera': 'Romanticismo', 'name': 'Dante', 'birth_year': '1265', 'death_year': '1321', 'linked_authors': 6}, {'id': 'Manuel A. Alonso', 'group': 8, 'country': 'Puerto Rico', 'genera': 'Romanticismo', 'name': 'Manuel A.', 'birth_year': '1822', 'death_year': '1889', 'linked_authors': 1}, {'id': 'Dámaso Alonso', 'group': 5, 'country': 'España', 'genera': 'nan', 'name': 'Dámaso', 'birth_year': '1898', 'death_year': '1990', 'linked_authors': 21}, {'id': 'Manuel Altolaguirre', 'group': 5, 'country': 'España', 'genera': 'nan', 'name': 'Manuel', 'birth_year': '1905', 'death_year': '1959', 'linked_authors': 17}, {'id': 'Pita Amor', 'group': 0, 'country': 'Mexico', 'genera': 'nan', 'name': 'Guinea', 'birth_year': '1918', 'death_year': '2000', 'linked_authors': 12}, {'id': 'Sophia de Mello Breyner Andresen', 'group': 9, 'country': 'Portugal', 'genera': 'nan', 'name': 'Sophia de Mello Breyner', 'birth_year': '1919', 'death_year': '2004', 'linked_authors': 2}, {'id': 'Guillaume Apollinaire', 'group': 10, 'country': 'Francia', 'genera': 'Romanticismo', 'name': 'Guillaume', 'birth_year': '1880', 'death_year': '1918', 'linked_authors': 1}, {'id': 'Louis Aragon', 'group': 10, 'country': 'Francia', 'genera': 'nan', 'name': 'Louis', 'birth_year': '1897', 'death_year': '1982', 'linked_authors': 6}, {'id': 'Rafael Arévalo Martínez', 'group': 12, 'country': 'Guatemala', 'genera': 'Realismo', 'name': 'Rafael', 'birth_year': '1884', 'death_year': '1975', 'linked_authors': 4}, {'id': 'Miguel Arteche', 'group': 14, 'country': 'Chile', 'genera': 'nan', 'name': 'Miguel', 'birth_year': '1926', 'death_year': '2012', 'linked_authors': 5}, {'id': 'María Victoria Atencia', 'group': 5, 'country': 'España', 'genera': 'Modernismo', 'name': 'María Victoria', 'birth_year': '1931', 'death_year': 'nan', 'linked_authors': 2}, {'id': 'Max Aub', 'group': 0, 'country': 'Mexico', 'genera': 'nan', 'name': 'Max', 'birth_year': '1903', 'death_year': '1972', 'linked_authors': 3}, {'id': 'Teresa de Jesús', 'group': 5, 'country': 'España', 'genera': 'nan', 'name': 'Santa Teresa de', 'birth_year': '1515', 'death_year': '1582', 'linked_authors': 9}, {'id': 'Emilio Ballagas', 'group': 15, 'country': 'Cuba', 'genera': 'nan', 'name': 'Emilio', 'birth_year': '1908', 'death_year': '1954', 'linked_authors': 4}, {'id': 'Carlos Barral', 'group': 5, 'country': 'España', 'genera': 'nan', 'name': 'Carlos', 'birth_year': '1928', 'death_year': '1989', 'linked_authors': 10}, {'id': 'Elizabeth Barrett Browning', 'group': 6, 'country': 'Inglaterra', 'genera': 'nan', 'name': 'Elizabeth', 'birth_year': '1806', 'death_year': '1861', 'linked_authors': 5}, {'id': 'José Batres Montúfar', 'group': 12, 'country': 'Guatemala', 'genera': 'Romanticismo', 'name': 'José', 'birth_year': '1809', 'death_year': '1844', 'linked_authors': 6}, {'id': 'Charles Baudelaire', 'group': 10, 'country': 'Francia', 'genera': 'Romanticismo', 'name': 'Charles', 'birth_year': ...

# %%
print(len(dataReduced['links']))
print(len(data['links']))
# Out:
# 5171
# 5587

# %%
# Save the JSON object to a file
with open('authorLinksSmaller.json', 'w') as outfile:
    json.dump(dataReduced, outfile,ensure_ascii=False)

# %% [markdown]
# ## Story Embeddings

# %%
db3.head(1)
# Out:
#           dim1          dim2         dim3  \
# 0  16,28848076  -8,153986931  8,296456337
#
#                               vector_id                            uuid_story  \
# 0  04d4cd4b-8f57-4910-8cff-cfd34ca6bf46  04d4cd4b-8f57-4910-8cff-cfd34ca6bf46
#
#                             author_uuid              story_name  \
# 0  9d50c449-ce8b-43f1-a0c1-53be4177dc93  Las vocales de colores
#
#                                                 link  length  words  \
# 0  https://ciudadseva.com/texto/las-vocales-de-co...    1765    305
#
#   reading_time_min                               coordinates
# 0            1,525  [16.28848076, -8.153986931, 8.296456337]

# %%
# prompt: convert db3 cols dim1, dim2, dim3 into a new one with float coordinates. They are currently strings like "16,0566546", so replace , with . and eval
df = pd.DataFrame()

df['story_name'] = db3['story_name']
df['x'] = [ float(d.replace(',', '.')) for d in db3['dim1'] ]
df['y'] = [ float(d.replace(',', '.')) for d in db3['dim2'] ]
df['z'] = [ float(d.replace(',', '.')) for d in db3['dim3'] ]
df.head()
# Out:
#                   story_name          x         y          z  size
# 0     Las vocales de colores  16.288481 -8.153987   8.296456   0.1
# 1        Cuánto se divertían  16.784241 -6.143554  10.079655   0.1
# 2          Todo lo contrario  19.959745 -9.638548   8.536081   0.1
# 3                   La carne  18.058767 -8.713723  10.635745   0.1
# 4  La rana gritona y el león  19.603294 -7.778275  12.218028   0.1

# %%
import plotly.express as px

# Big figure plotly
fig = px.scatter_3d(df, x='x', y='y', z='z',text='story_name')
fig.update_traces(mode = 'markers')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="08bd30b0-ed5b-4bba-9817-e34f177e5f1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08bd30b0-ed5b-4bba-9817-e34f177e5f1a")) {                    Plotly.newPlot(                        "08bd30b0-ed5b-4bba-9817-e34f177e5f1a",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cbr\u003estory_name=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"text":["Las vocales de colores","Cu\u00e1nto se divert\u00edan","Todo lo contrario","La carne","La rana gritona y el le\u00f3n","Nada con exceso","Margarita o El poder de la farmacopea","La ni\u00f1a de los tres maridos","Los vecinos del principal derecha","El sexo de los \u00e1ngeles","Rumpelstikin","Profundidad china","Metamorfosis","La liebre y la tortuga","Cuento VII \u2013 El conde Lucanor \u2013 Do\u00f1a Truhana","Pigmali\u00f3n","La pasarela","El poder","El rey de los monos","Cuento de los tres deseos","La ley de Herodes","El primer destilador","Los piojitos de la princesa","La casa embrujada","Los gatos de Ulthar","El gato y la zorra","De funerales","El pollito que se hizo rey","EL Zorro y los Pavos","Las estatuas","El muerto en el mar de Urca","Para objetos solamente","El cometa","Rutinas","F\u00e1bula","Los lobos y los perros alist\u00e1ndose a luchar","En tierra firme","El grillo maestro","En una estaci\u00f3n de ferrocarril","Los animales en el arca","El grupo","La leyenda de Carlomagno","Ley profunda","Dios y el p\u00e1rroco","Tristis imago","La princesa y el frijol","El enigma","En el Santo","La higuera","En Zaccarath","Vamos a matar los Gaticos","Los jugadores de ajedrez","Dichos de Luder 37","Prejaspes","El martirio de sor Bibiana","La primera conquista","F\u00e1bula hind\u00fa","La vida en com\u00fan","Los hombres m\u00e1s nobles y antiguos","Jab\u00f3n","El hombre y su imagen","La f\u00e1bula de los ciegos","El ratoncillo, el pajarillo y la salchicha","El puente","En la barber\u00eda","Los dos pichones","Un ni\u00f1o como yo","Sadismo y masoquismo","In memoriam Dr. KHG","S\u00e9 como un muerto","Sim\u00f3n el mago","El salto cualitativo","En el caf\u00e9 de la estaci\u00f3n","El gerente","De puro distra\u00eddo","La zorra y el perro","Despedida","El alma humana: un abismo","Los campeones de salto","El genio del pesacartas","El hombre en la noche","La pulga y el profesor","Schehrasad en la noche 1002","Final","Chacales y \u00e1rabes","Las aventuras del cardo","El l\u00e1piz","Aniversario","Mariposas y cornetas","Un preso singular","A\u00f1o nuevo","El oro ingl\u00e9s","La Muerte y el Desdichado","El pa\u00eds con el \u201cdes\u201d delante","Arturo y el mago Merl\u00edn","La sangre","La cruz de Salom\u00f3n","Justificaci\u00f3n de la mujer de Putifar","La pistola","Esquina peligrosa","No son invenciones de poetas","Las tres de la ma\u00f1ana","La vieja pordiosera","Gorrioncito","Casa di Amore e Psyche","La \u00faltima noche del mundo","El viejo cofre de Nuri Bey","La mojiganga (1753)","Culebra ser\u00e1","El \u00e1rbol del orgullo","La intrusa","M\u00fasica de ma\u00f1ana","Todo por la compa\u00f1\u00eda","Sorpresa","El pensador de Rodin","Cruce de caminos","Topos","Los dos consolados","Ictiocentauros","Fe","Asnos est\u00fapidos","La ni\u00f1a de la caja de cristal","Aniuta","El oro","Casa en el mar","Moverse del lado del espejo","Una broma del maestro","El ni\u00f1o travieso","La v\u00edbora y la culebra de agua","La viga","Un obispo en el atolladero","Reconciliaci\u00f3n","El silencio de las sirenas","En la peluquer\u00eda","El caballito blanco H\u00fch\u00fc","Santa Clo va a La Cuchilla","La n ...

# %%
fig = px.scatter(df,'x','y',text='story_name')
fig.update_traces(mode = 'markers')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="158d95e9-27af-485e-b489-15ea8fb548ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("158d95e9-27af-485e-b489-15ea8fb548ef")) {                    Plotly.newPlot(                        "158d95e9-27af-485e-b489-15ea8fb548ef",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003estory_name=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"text":["Las vocales de colores","Cu\u00e1nto se divert\u00edan","Todo lo contrario","La carne","La rana gritona y el le\u00f3n","Nada con exceso","Margarita o El poder de la farmacopea","La ni\u00f1a de los tres maridos","Los vecinos del principal derecha","El sexo de los \u00e1ngeles","Rumpelstikin","Profundidad china","Metamorfosis","La liebre y la tortuga","Cuento VII \u2013 El conde Lucanor \u2013 Do\u00f1a Truhana","Pigmali\u00f3n","La pasarela","El poder","El rey de los monos","Cuento de los tres deseos","La ley de Herodes","El primer destilador","Los piojitos de la princesa","La casa embrujada","Los gatos de Ulthar","El gato y la zorra","De funerales","El pollito que se hizo rey","EL Zorro y los Pavos","Las estatuas","El muerto en el mar de Urca","Para objetos solamente","El cometa","Rutinas","F\u00e1bula","Los lobos y los perros alist\u00e1ndose a luchar","En tierra firme","El grillo maestro","En una estaci\u00f3n de ferrocarril","Los animales en el arca","El grupo","La leyenda de Carlomagno","Ley profunda","Dios y el p\u00e1rroco","Tristis imago","La princesa y el frijol","El enigma","En el Santo","La higuera","En Zaccarath","Vamos a matar los Gaticos","Los jugadores de ajedrez","Dichos de Luder 37","Prejaspes","El martirio de sor Bibiana","La primera conquista","F\u00e1bula hind\u00fa","La vida en com\u00fan","Los hombres m\u00e1s nobles y antiguos","Jab\u00f3n","El hombre y su imagen","La f\u00e1bula de los ciegos","El ratoncillo, el pajarillo y la salchicha","El puente","En la barber\u00eda","Los dos pichones","Un ni\u00f1o como yo","Sadismo y masoquismo","In memoriam Dr. KHG","S\u00e9 como un muerto","Sim\u00f3n el mago","El salto cualitativo","En el caf\u00e9 de la estaci\u00f3n","El gerente","De puro distra\u00eddo","La zorra y el perro","Despedida","El alma humana: un abismo","Los campeones de salto","El genio del pesacartas","El hombre en la noche","La pulga y el profesor","Schehrasad en la noche 1002","Final","Chacales y \u00e1rabes","Las aventuras del cardo","El l\u00e1piz","Aniversario","Mariposas y cornetas","Un preso singular","A\u00f1o nuevo","El oro ingl\u00e9s","La Muerte y el Desdichado","El pa\u00eds con el \u201cdes\u201d delante","Arturo y el mago Merl\u00edn","La sangre","La cruz de Salom\u00f3n","Justificaci\u00f3n de la mujer de Putifar","La pistola","Esquina peligrosa","No son invenciones de poetas","Las tres de la ma\u00f1ana","La vieja pordiosera","Gorrioncito","Casa di Amore e Psyche","La \u00faltima noche del mundo","El viejo cofre de Nuri Bey","La mojiganga (1753)","Culebra ser\u00e1","El \u00e1rbol del orgullo","La intrusa","M\u00fasica de ma\u00f1ana","Todo por la compa\u00f1\u00eda","Sorpresa","El pensador de Rodin","Cruce de caminos","Topos","Los dos consolados","Ictiocentauros","Fe","Asnos est\u00fapidos","La ni\u00f1a de la caja de cristal","Aniuta","El oro","Casa en el mar","Moverse del lado del espejo","Una broma del maestro","El ni\u00f1o travieso","La v\u00edbora y la culebra de agua","La viga","Un obispo en el atolladero","Reconciliaci\u00f3n","El silencio de las sirenas","En la peluquer\u00eda","El caballito blanco H\u00fch\u00fc","Santa Clo va a La Cuchilla","La naturaleza es una madre cruel","Esa p ...
